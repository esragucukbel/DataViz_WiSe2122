# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import zipfile

# %% [markdown]
# ## Data Exploration

# %%
with zipfile.ZipFile("owid-covid-data.zip") as z:
    with z.open("owid-covid-data.json") as f:
        covid_data = pd.read_json(f)

# %%
covid_data = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")
covid_data.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 65 columns]

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127314 entries, 0 to 127313
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 127314 non-null  object
#  1   continent                                121556 non-null  object
#  2   location                                 127314 non-null  object
#  3   date                                     127314 non-null  object
#  4   total_cases                              120366 non-null  float64
#  5   new_cases                                120362 non-null  float64
#  6   new_cases_smoothed                       119348 non-null  float64
#  7   total_deaths                             109388 non-null  float64
#  8   new_deaths                               109541 non-null  float64
#  9   new_deaths_smoothed                      119348 non-null  float64
#  10  total_cases_per_million                  119734 non-null  float64
#  11  new_cases_per_million                    119730 non-null  float64
#  12  new_cases_smoothed_per_million           118721 non-null  float64
#  13  total_deaths_per_million                 108769 non-null  float64
#  14  new_deaths_per_million                   108922 non-null  float64
#  15  new_deaths_smoothed_per_million          118721 non-null  float64
#  16  reproduction_rate                        102576 non-null  float64
#  17  icu_patients                             14602 non-null   float64
#  18  icu_patients_per_million                 14602 non-null   float64
#  19  hosp_patients                            17243 non-null   float64
#  20  hosp_patients_per_million                17243 non-null   float64
#  21  weekly_icu_admissions                    1232 non-null    float64
#  22  weekly_icu_admissions_per_million        1232 non-null    float64
#  23  weekly_hosp_admissions                   2132 non-null    float64
#  24  weekly_hosp_admissions_per_million       2132 non-null    float64
#  25  new_tests                                54371 non-null   float64
#  26  total_tests                              54548 non-null   float64
#  27  total_tests_per_thousand                 54548 non-null   float64
#  28  new_tests_per_thousand                   54371 non-null   float64
#  29  new_tests_smoothed                       65725 non-null   float64
#  30  new_tests_smoothed_per_thousand          65725 non-null   float64
#  31  positive_rate                            61743 non-null   float64
#  32  tests_per_case                           61087 non-null   float64
#  33  tests_units                              67711 non-null   object
#  34  total_vaccinations                       30782 non-null   float64
#  35  people_vaccinated                        29241 non-null   float64
#  36  people_fully_vaccinated                  26217 non-null   float64
#  37  total_boosters                           4557 non-null    float64
#  38  new_vaccinations                         25468 non-null   float64
#  39  new_vaccinations_smoothed                55516 non-null   float64
#  40  total_vaccinations_per_hundred           30782 non-null   float64
#  41  people_vaccinated_per_hundred            29241 non-null   float64
#  42  people_fully_vaccinated_per_hundred      26217 non-null   float64
#  43  total_boosters_per_hundred               4557 non-null    float64
#  44  new_vaccinations_smoothed_per_million    55516 non-null   float64
#  45  stringency_index                         105722 non-null  float64
#  46  population                               126400 non-null  float64
#  47  population_density                       117594 non-null  float64
#  48  median_age                               112128 non-null  float64
#  49  aged_65_older                            110886 non-null  float64
#  50  aged_70_older                            111515 non-null  float64
#  51  gdp_per_capita                           112851 non-null  float64
#  52  extreme_poverty                          75504 non-null   float64
#  53  cardiovasc_death_rate                    112391 non-null  float64
#  54  diabetes_prevalence                      116021 non-null  float64
#  55  female_smokers                           87556 non-null   float64
#  56  male_smokers                             86288 non-null   float64
#  57  handwashing_facilities                   56573 non-null   float64
#  58  hospital_beds_per_thousand               102147 non-null  float64
#  59  life_expectancy                          120741 non-null  float64
#  60  human_development_index                  112482 non-null  float64
#  61  excess_mortality_cumulative_absolute     4568 non-null    float64
#  62  excess_mortality_cumulative              4568 non-null    float64
#  63  excess_mortality                         4568 non-null    float64
#  64  excess_mortality_cumulative_per_million  4568 non-null    float64
# dtypes: float64(60), object(5)
# memory usage: 63.1+ MB

# %%
# Max of total_cases column
covid_data.total_cases.max()
# Out:
# 246407250.0

# %%
# Max of positive_rate
covid_data.positive_rate.max()
# Out:
# 0.97

# %%
# Show the data of havıng max total cases row
covid_data.loc[ covid_data.total_cases.idxmax() ]
# Out:
# iso_code                                      OWID_WRL
# continent                                          NaN
# location                                         World
# date                                        2021-10-30
# total_cases                                246407250.0
#                                               ...
# human_development_index                          0.737
# excess_mortality_cumulative_absolute               NaN
# excess_mortality_cumulative                        NaN
# excess_mortality                                   NaN
# excess_mortality_cumulative_per_million            NaN
# Name: 125562, Length: 65, dtype: object

# %%
# Calculate mean of total_case, new_cases,new_deaths
covid_data[['total_cases', 'new_cases', 'new_deaths']].mean(axis=0)
# Out:
# total_cases    1.536968e+06
# new_cases      6.463036e+03
# new_deaths     1.436271e+02
# dtype: float64

# %% [markdown]
# ## Data Visualization

# %%
data = covid_data.groupby(by=['continent']).sum().reset_index()
data
# Out:
#        continent   total_cases   new_cases  new_cases_smoothed  total_deaths  \
# 0         Africa  1.966430e+09   8496089.0        8.482790e+06    50205783.0
# 1           Asia  1.670223e+10  78453109.0        7.814659e+07   252232564.0
# 2         Europe  1.557933e+10  65138548.0        6.442209e+07   370647073.0
# 3  North America  1.403475e+10  55222989.0        5.496846e+07   328086690.0
# 4        Oceania  2.942908e+07    258286.0        2.522845e+05      542889.0
# 5  South America  9.939450e+09  38211595.0        3.815020e+07   315432743.0
#
#    new_deaths  new_deaths_smoothed  total_cases_per_million  \
# 0    218099.0           217558.395             1.621350e+08
# 1   1174690.0          1169346.753             4.669102e+08
# 2   1304566.0          1294693.651             1.132716e+09
# 3   1121054.0          1114974.588             2.175013e+08
# 4      2805.0             2738.057             6.882027e+06
# 5   1157308.0          1155910.255             2.015592e+08
#
#    new_cases_per_million  new_cases_smoothed_per_million  ...  female_smokers  \
# 0             840318.055                      838235.281  ...         55178.6
# 1            2171831.619                     2156416.476  ...        112438.2
# 2            4674464.641                     4616689.164  ...        578521.7
# 3            1215543.898                     1204592.989  ...         55960.5
# 4              69471.996                       68937.684  ...         59603.3
# 5             859708.579                      857492.229  ...         61147.7
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0      587102.2              663271.457                   35870.540
# 1      930290.2             1104017.288                   78487.570
# 2      878049.8              171047.325                  136973.811
# 3      163499.9              609539.863                   32062.600
# 4      122812.8               53091.691                    8943.670
# 5      121186.2              238341.648                   15405.700
#
#    life_expectancy  human_development_index  \
# 0     2.065248e+06                17678.583
# 1     2.198945e+06                21143.162
# 2     2.283448e+06                22848.604
# 3     1.247978e+06                10515.356
# 4     4.431564e+05                 3395.732
# 5     5.591701e+05                 5632.033
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                             8575547.2                       950.50
# 1                             9576888.6                      4204.22
# 2                            44100410.0                     14981.04
# 3                            55941161.2                      4677.36
# 4                             -254917.6                      -457.67
# 5                            22799657.5                     14410.19
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0           2568.62                             1.108297e+05
# 1           8569.98                             2.534179e+05
# 2          32276.13                             2.111611e+06
# 3           8566.26                             3.439083e+05
# 4           -330.86                            -3.196724e+04
# 5          20118.95                             6.733218e+05
#
# [6 rows x 61 columns]

# %%
alt.Chart(data).mark_bar().encode(
x= 'continent',
y='new_cases')
# Out:
# alt.Chart(...)

# %%
# Task: Change x and y axes
alt.Chart(data).mark_bar().encode(
y= 'continent',
x='new_cases')
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_bar().encode(
x= 'continent',
y='new_cases',
tooltip =['new_cases_per_million','new_deaths']).properties(
    width = 200,
    height= 200
    
)
# Out:
# alt.Chart(...)
